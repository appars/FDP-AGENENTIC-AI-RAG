# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarsirish/rag-workshop/blob/main/college-department-rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG (Retrieval-Augmented Generation) System
# ## Fictional Undergrad Department - DISE (Department of Intelligent Systems Engineering)
#
# This notebook demonstrates building a basic RAG pipeline for question-answering about a fictional department (DISE).
#
# ## What We'll Build:
#
# 1. **Document Embedding** - Convert text documents into vector representations using `all-MiniLM-L6-v2`
# 2. **Vector Index** - Create a FAISS index for fast similarity search
# 3. **Retrieval** - Find relevant documents based on user queries using cosine similarity
# 4. **Generation** - Use Llama 3.1-8B (via HuggingFace API) to generate answers from retrieved context
#
# ## Key Technologies:
# - **SentenceTransformers**: Open-source embedding model
# - **FAISS**: Facebook's similarity search library
# - **HuggingFace Inference API**: Free LLM access without local model download
#
# ## Simplifications:
# - No document chunking (documents are already small)
# - No authentication required (using free HF inference)
# - Minimal preprocessing for educational clarity

# %% [markdown]
# ## Setup Instructions (Optional)
#
# ### Getting a HuggingFace Token:
#
# While this notebook uses HuggingFace's free inference API that works without authentication for some models, having a token provides better rate limits and access to more models.
#
# **Steps to get your free HF token:**
#
# 1. Visit [https://huggingface.co/](https://huggingface.co/) and sign up (free)
# 2. Go to [https://huggingface.co/settings/tokens](https://huggingface.co/settings/tokens)
# 3. Click **"New token"** → Give it a name → Select **"Read"** access
# 4. Copy the generated token
# 5. Set it in your environment:
#    ```bash
#    export HF_TOKEN="your_token_here"
#    ```
#    Or in Python:
#    ```python
#    import os
#    os.environ["HF_TOKEN"] = "your_token_here"
#    ```
#    Or if running in Google Collab, then copy the token to the secrets with key as HF_TOKEN
#
#
# **Note**: Add a token or you may encounter rate limits or want access to gated models.

# %%
! pip install faiss-cpu sentence-transformers
import faiss #Facebook AI Similarity Search
from sentence_transformers import SentenceTransformer
from huggingface_hub import InferenceClient


# Load open-source embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
print(f"Loaded embedding model: all-MiniLM-L6-v2")
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.4.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from faiss-cpu) (2.4.4)
# Requirement already satisfied: packaging in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from faiss-cpu) (26.2)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.7.0-py3-none-any.whl.metadata (33 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.13.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: torch>=1.11.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: filelock>=3.10.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.4.0)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Using cached hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.13)
# Requirement already satisfied: h11>=0.16 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/sirkumar/python3.14_venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# Downloading sentence_transformers-5.4.1-py3-none-any.whl (571 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.3/571.3 kB 2.0 MB/s  0:00:0036m-:--:--
# Downloading transformers-5.7.0-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 2.9 MB/s  0:00:03m0:00:010:01
# Downloading huggingface_hub-1.13.0-py3-none-any.whl (660 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.6/660.6 kB 2.5 MB/s  0:00:00m eta 0:00:01
# Using cached hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Installing collected packages: safetensors, hf-xet, faiss-cpu, huggingface-hub, tokenizers, transformers, sentence-transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [sentence-transformers]ence-transformers]
# Successfully installed faiss-cpu-1.13.2 hf-xet-1.4.3 huggingface-hub-1.13.0 safetensors-0.7.0 sentence-transformers-5.4.1 tokenizers-0.22.2 transformers-5.7.0
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loaded embedding model: all-MiniLM-L6-v2

# %%
#Sample documents to index

fictious_department_info = [
"The Department of Intelligent Systems Engineering (DISE) is a small, focused department that works on applied AI and intelligent systems.",
"It currently has around 40 students, with a healthy mix of undergraduate and postgraduate learners.",
"The department is run by a team of 14 professors, including experienced faculty members and a few industry practitioners.",
"Students can choose from about 5 courses, ranging from core subjects to electives and hands-on project work.",
"Overall, DISE aims to prepare students for real-world engineering roles through practical learning and industry exposure."
]

# %%
#Generate embeddings for the documents using sentence-transformers
def generate_embeddings(documents):
    embeddings = embedding_model.encode(documents, convert_to_numpy=True)
    return embeddings.astype("float32") #float32 array is required for FAISS

# %%
embeddings = generate_embeddings(fictious_department_info)
dimension = embeddings.shape[1]
print(f"Generated Embeddings: {embeddings}, Shape: {embeddings.shape}")
# Out:
# Generated Embeddings: [[-0.07132276 -0.05098747  0.08233205 ...  0.04680338  0.10476345
#    0.01670633]
#  [ 0.14424947 -0.07723177  0.03562665 ... -0.06226517 -0.02721871
#    0.05241624]
#  [ 0.0424109  -0.07360022  0.01778188 ... -0.04113436  0.03309242
#   -0.00423288]
#  [ 0.02437476 -0.06608857  0.02731377 ...  0.00646836 -0.03955945
#    0.04772925]
#  [-0.0733059  -0.02780114  0.06805544 ...  0.00475259  0.02320011
#    0.07533488]], Shape: (5, 384)

# %%
#Create FAISS index with ineer product metric - for cosine similarity
faiss.normalize_L2(embeddings)
index = faiss.IndexFlatIP(dimension)
index.add(embeddings)
print(f"Number of documents indexed: {index.ntotal}")
# Out:
# Number of documents indexed: 5

# %%
# Search FAISS index for top_k documents similar to the query
def search_index(query, top_k=2):
    query_embedding = generate_embeddings([query])
    faiss.normalize_L2(query_embedding) # Normalize the query embedding to unit length
    distances, indices = index.search(query_embedding, top_k)

    results = []
    for idx, i in enumerate(indices[0]):
        results.append((fictious_department_info[i], distances[0][idx]))

    return results

# %%
user_query = "Whats the full form of DICE?"
#user_query = "How many students in DISE"
#user_query = "how many casual leaves can i get"

# %%
#retrieve documents based on the query
retrieved_docs = search_index(user_query, top_k=2)
print("Top retrieved documents:")
for doc, score in retrieved_docs:
    print(f"Document: {doc}, Score: {score}")
# Out:
# Top retrieved documents:
# Document: Students can choose from about 5 courses, ranging from core subjects to electives and hands-on project work., Score: 0.15158578753471375
# Document: The Department of Intelligent Systems Engineering (DISE) is a small, focused department that works on applied AI and intelligent systems., Score: 0.08317936956882477

# %%
#Build prompt with retrieved documents
def build_prompt(query, retrieved_docs):
    context_lines = []
    for doc, _ in retrieved_docs:
        context_lines.append(f"- {doc}")
    context = "\n".join(context_lines)
    prompt = f"Based on the following documents:\n{context}\nAnswer the question: {query}"

    return prompt

# %%
# Build prompt
user_prompt = build_prompt(user_query, retrieved_docs)
rag_prompt = [
    #{"role": "system", "content": "You are a helpful assistant. You must always answer the question asked"},
     {"role": "system", "content": "You are a helpful assistant. Strictly use the provided documents to answer the user's question."},
     {"role": "user", "content": user_prompt}

]

simple_prompt = [
    {"role": "system", "content": "You are a helpful assistant. You must always answer"},
      {"role": "user", "content": user_query}

]

print(f"RAG Prompt: {rag_prompt}\n")
print(f"Simple prompt: {simple_prompt}")
# Out:
# RAG Prompt: [{'role': 'system', 'content': "You are a helpful assistant. Strictly use the provided documents to answer the user's question."}, {'role': 'user', 'content': 'Based on the following documents:\n- Students can choose from about 5 courses, ranging from core subjects to electives and hands-on project work.\n- The Department of Intelligent Systems Engineering (DISE) is a small, focused department that works on applied AI and intelligent systems.\nAnswer the question: Whats the full form of DICE?'}]
#
# Simple prompt: [{'role': 'system', 'content': 'You are a helpful assistant. You must always answer'}, {'role': 'user', 'content': 'Whats the full form of DICE?'}]

# %% [markdown]
# Reference: https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct
# <br><b>
# The size of the model in terms of parameters is 8B.  '8B' means it has 8 billion parameters. This is considered a relatively small model compared to larger versions (like 70B or even larger proprietary models), making it efficient for deployment on consumer hardware or for tasks where speed and lower resource usage are critical, while still offering good capabilities.
# </b>

# %%
def get_response(prompt):
  response = client.chat_completion(
    model="meta-llama/Llama-3.1-8B-Instruct",
    messages=prompt,
    max_tokens=150,
    temperature=0.9
  )
  answer = response.choices[0].message.content
  return answer

# %%
import os
from google.colab import userdata

# Use HuggingFace Inference API (free, no auth required for some models)

#hf_token = userdata.get('HF_TOKEN').strip()

#client = InferenceClient(token=hf_token)
client = InferenceClient()
response = get_response(rag_prompt)
print(f"Generated Answer with RAG: {response}")

response = get_response(simple_prompt)
print(f"\nGenerated Answer without RAG: {response}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import os
# ----> 2 from google.colab import userdata
#       3
#       4 # Use HuggingFace Inference API (free, no auth required for some models)
#       5
#
# ModuleNotFoundError: No module named 'google.colab'
